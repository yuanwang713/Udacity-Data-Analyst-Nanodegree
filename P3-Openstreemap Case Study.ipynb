# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import os
import pymongo

# %%
shh_data = "brooklyn_new-york.osm"

# %%
#Parse through the file with ElementTree and count the number of unique element types to understand overall structure.
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
shh_tags = count_tags(shh_data)
pprint.pprint(shh_tags)
# Out:
# {'bounds': 1,
#  'member': 14551,
#  'nd': 3494969,
#  'node': 2484785,
#  'osm': 1,
#  'relation': 1701,
#  'tag': 2819240,
#  'way': 490294}

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

shh_keys = process_map(shh_data)
pprint.pprint(shh_keys)
# Out:
# {'lower': 1052673,
#  'lower_colon': 1745044,
#  'other': 7239,
#  'problemchars': 14284}

# %%
#people invovlved in the map editing.
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = process_map(shh_data)
len(users)
# Out:
# 1384

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail"]

mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'street' :"Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square"}

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
shh_street_types = audit(shh_data)

# %%
pprint.pprint(dict(shh_street_types))
# Out:
# {'1': set(['Graham Avenue #1']),
#  '11217': set(['305 Schermerhorn St., Brooklyn, NY 11217']),
#  '1st': set(['1st']),
#  '218650358': set(['218650358']),
#  '3': set(['Hanover Square #3']),
#  '300': set(['Ste 300']),
#  '4B': set(['Union Avenue 4B']),
#  '500': set(['Main St., Suite 500']),
#  '861': set(['861']),
#  'A': set(['Avenue A']),
#  'Alley': set(['Cortlandt Alley',
#                'Exchange Alley',
#                'Freeman Alley',
#                'Grace Court Alley',
#                'Harrison Alley',
#                'Mac Dougal Alley',
#                'Theater Alley']),
#  'Americas': set(['Avenue Of The Americas',
#                   'Avenue of the Americas',
#                   'Avenue of the Americas\n']),
#  'Atrium': set(['Broadway Atrium']),
#  'Ave': set(['4th Ave', '5th Ave', '6th Ave', 'Norman Ave', 'Park Ave']),
#  'Ave.': set(['Washington Ave.']),
#  'Avene': set(['Nostrand Avene']),
#  'Avenue,': set(['70th Avenue,']),
#  'B': set(['Avenue B']),
#  'Bayside': set(['Bayside']),
#  'Blvd': set(['Marin Blvd', 'Queens Blvd', 'Woodhaven Blvd']),
#  'Bowery': set(['Bowery', 'The Bowery']),
#  'Broadway': set(['Broadway',
#                   'East Broadway',
#                   'W. Broadway',
#                   'West Broadway']),
#  'Bushwick': set(['Bushwick']),
#  'C': set(['2nd Street #C', 'Avenue C']),
#  'Center': set(['Metrotech Center',
#                 'One World Trade Center',
#                 'World Financial Center',
#                 'World Trade Center']),
#  'Circle': set(['Hamilton Circle', 'Middlemay Circle']),
#  'Clinton': set(['Clinton']),
#  'Close': set(['Fairway Close', 'Ivy Close']),
#  'Crescent': set(['Asquith Crescent',
#                   'Boelsen Crescent',
#                   'Cromwell Crescent',
#                   'Dieterle Crescent',
#                   'Ellwell Crescent',
#                   'Mt Olivet Crescent',
#                   'Slocum Crescent']),
#  'Ctr': set(['Harborside Fin Ctr']),
#  'D': set(['Avenue D']),
#  'East': set(['Anthony J Falco Square East',
#               'Boardwalk East',
#               'Cadman Plaza East',
#               'Fdr Drive Service Road East',
#               'Gouverneur Slip East',
#               'Gramercy Park East',
#               'Marginal St East',
#               'Oceana Drive East',
#               'Park Drive East',
#               'Plaza Street East',
#               'Union Square East',
#               'Village Road East',
#               'Washington Square East',
#               'Williamsburg Street East']),
#  'Expressway': set(['Horace Harding Expressway']),
#  'Extension': set(['Eastern Parkway Extension', 'Flatbush Avenue Extension']),
#  'F': set(['Avenue F']),
#  'Finest': set(['Avenue Of The Finest']),
#  'Floor)': set(['Manhattan Avenue (2nd Floor)']),
#  'Fulton': set(['Old Fulton']),
#  'Gardens': set(['Colonial Gardens']),
#  'Gratta': set(['Gratta']),
#  'H': set(['Avenue H']),
#  'Hamilton': set(['Fort Hamilton']),
#  'Heights': set(['Columbia Heights']),
#  'Highway': set(['Kings Highway']),
#  'I': set(['Avenue I']),
#  'Island': set(['Governors Island']),
#  'J': set(['Avenue J']),
#  'K': set(['Avenue K']),
#  'L': set(['Avenue L']),
#  'Loop': set(['14th Street Loop',
#               'Ardsley Loop',
#               'Bethel Loop',
#               'Croton Loop',
#               'Delmar Loop',
#               'Elmira Loop',
#               'Freeport Loop',
#               'Geneva Loop',
#               'Hornell Loop',
#               'Sheridan Loop']),
#  'M': set(['Avenue M']),
#  'Macdougal': set(['Macdougal']),
#  'Mall': set(['Centre Mall']),
#  'MetroTech': set(['MetroTech']),
#  'Mews': set(['Greenwich Mews', 'Washington Mews']),
#  'N': set(['Avenue N']),
#  'North': set(['Barlow Drive North',
#                'Gaylord Drive North',
#                'Gramercy Park North',
#                'Greenway North',
#                'Horace Harding Expressway Service Road North',
#                'Juniper Boulevard North',
#                'Marshall Drive North',
#                'Mayfair Drive North',
#                'Paerdegat Avenue North',
#                'Queens Midtown Expressway Service Road North',
#                'Shore Parkway Sr North',
#                'Village Road North',
#                'Washington Square North']),
#  'O': set(['Avenue O']),
#  'Oval': set(['Grand Army Plaza Oval', 'Stuyvesant Oval']),
#  'P': set(['Avenue P']),
#  'PH': set(['Harrison Street Suite PH']),
#  'Park': set(['Gramercy Park', 'Washington Park']),
#  'Path': set(['Brighton 10th Path', 'Brighton 1st Path', 'Brighton 2nd Path']),
#  'Piers': set(['Northside Piers']),
#  'Plaza': set(['American Express Plaza',
#                'Battery Park Plaza',
#                'Brookdale Plaza',
#                'Chase Manhattan Plaza',
#                'Confucius Plaza',
#                'Exchange Plaza',
#                'Federal Plaza',
#                'Federal Reserve Plaza',
#                'Hanover Plaza',
#                'Haven Plaza',
#                'Kings Plaza',
#                'Lefrak City Plaza',
#                'Liberty Plaza',
#                'Marine View Plaza',
#                'New York Plaza',
#                'Newkirk Plaza',
#                'Pace Plaza',
#                'Police Plaza',
#                'Saint Andrews Plaza',
#                'Samuel Dickstein Plaza',
#                'Seaport Plaza',
#                'State Street Plaza',
#                'Wall Street Plaza',
#                'Waterside Plaza',
#                'Western Union Plaza']),
#  'Promenade': set(['Ocean Promenade']),
#  'R': set(['Avenue R']),
#  'Rb': set(['Linden Boulevard Outer Eb Rb']),
#  'Rd': set(['Aviation Rd']),
#  'Remsen': set(['Remsen']),
#  'Reservation': set(['Beach Reservation']),
#  'Rico': set(['Avenue Of Puerto Rico']),
#  'Roadbed': set(['4th Avenue Southbound Roadbed',
#                  'Delancey Street Eb Roadbed',
#                  'Delancey Street Wb Roadbed',
#                  'Gateway Drive Westbound Roadbed',
#                  'Kings Highway Westbound Roadbed',
#                  'Linden Boulevard Eb Roadbed',
#                  'Ocean Parkway Southbound Roadbed',
#                  'Pennsylvania Avenue Nb Roadbed',
#                  'Queens Boulevard Wb Roadbed']),
#  'Rockaways': set(['Hillside Avenue Rockaways']),
#  'Row': set(['Park Row']),
#  'S': set(['Avenue S', 'Horace Harding Expressway Sr S']),
#  'ST': set(['N 9th ST']),
#  'Slip': set(['Catherine Slip',
#               'Coenties Slip',
#               'Old Slip',
#               'Peck Slip',
#               'Pike Slip',
#               'Rutgers Slip']),
#  'South': set(['7th Avenue South',
#                'Barlow Drive South',
#                'Craig Road South',
#                'Delancey St South',
#                'Gaylord Drive South',
#                'Gramercy Park South',
#                'Greenway South',
#                'Horace Harding Expressway Service Road South',
#                'Juniper Boulevard South',
#                'Marshall Drive South',
#                'Mayfair Drive South',
#                'Mc Guinness Boulevard South',
#                'Paerdegat Avenue South',
#                'Park Avenue South',
#                'Park Lane South',
#                'Queens Midtown Expressway Service Road South',
#                'River Drive South',
#                'Shore Parkway Sr South',
#                'Village Road South',
#                'Washington Square South']),
#  'Southwest': set(['Prospect Park Southwest']),
#  'St': set(['1st St',
#             '2nd St',
#             '362nd Grand St',
#             '8th St',
#             '9th St',
#             'Adams St',
#             'Bloomfield St',
#             'Clinton St',
#             'E 15th St',
#             'Garden St',
#             'Grand St',
#             'Hudson St',
#             'Jackson St',
#             'Jefferson St',
#             'Madison St',
#             'Monroe St',
#             'N 7th St',
#             'Newark St',
#             'River St',
#             'Schermerhorn St',
#             'Smith St & Bergen St',
#             'State St & Water St',
#             'Union St',
#             'Washington St']),
#  'St.': set(['11th St.',
#              '9th St.',
#              'Devoe St.',
#              'Harrison St.',
#              'Henry St.',
#              'Schermerhorn St.',
#              'South 4th St.',
#              'Warren St.',
#              'Washington St.']),
#  'Steet': set(['West 8th Steet']),
#  'Streeet': set(['Johnson Streeet']),
#  'T': set(['Avenue T']),
#  'Terrace': set(['56th Terrace',
#                  'Albemarle Terrace',
#                  'Banner 3rd Terrace',
#                  'Barwell Terrace',
#                  'Bay Cliff Terrace',
#                  'Bliss Terrace',
#                  'Brighton 10th Terrace',
#                  'Brighton 1st Terrace',
#                  'Brighton 4th Terrace',
#                  'Greenway Terrace',
#                  'Harbor View Terrace',
#                  'Kenmore Terrace',
#                  'Lincoln Terrace',
#                  'Losee Terrace',
#                  'Louise Terrace',
#                  'Montague Terrace',
#                  'Oceana Terrace',
#                  'Park End Terrace',
#                  'Perry Terrace',
#                  'Ridgecrest Terrace',
#                  'River Terrace',
#                  'Roxbury Terrace',
#                  'Tudor Terrace',
#                  'Wogan Terrace']),
#  'Turnpike': set(['Union Turnpike']),
#  'U': set(['Avenue U']),
#  'V': set(['Avenue V']),
#  'Vanderbilt': set(['Vanderbilt']),
#  'Village': set(['Washington Square Village']),
#  'W': set(['Avenue W']),
#  'Walk': set(['Arcadia Walk',
#               'Atlantic Walk',
#               'Bath Walk',
#               'Bayside Walk',
#               'Bayview Walk',
#               'Bayway Walk',
#               'Brant Walk',
#               'Brighton 1st Walk',
#               'Brighton 2nd Walk',
#               'Brighton 3rd Walk',
#               'Brighton 4th Walk',
#               'Brighton 5th Walk',
#               'Brighton 7th Walk',
#               'Chester Walk',
#               'Clinton Walk',
#               'Cumberland Walk',
#               'Deaville Walk',
#               'Devon Walk',
#               'East 4th Walk',
#               'Essex Walk',
#               'Fleet Walk',
#               'Fulton Walk',
#               'Gotham Walk',
#               'Hamilton Walk',
#               'Hillcrest Walk',
#               'Hudson Walk',
#               'Irving Walk',
#               'Jamaica Walk',
#               'Jones Walk',
#               'Kildare Walk',
#               'Kingsborough 1st Walk',
#               'Kingsborough 2nd Walk',
#               'Kingsborough 3rd Walk',
#               'Kingsborough 4th Walk',
#               'Kingsborough 5th Walk',
#               'Kingsborough 6th Walk',
#               'Kingsborough 7th Walk',
#               'Lafayette Walk',
#               'Lincoln Walk',
#               'Marion Walk',
#               'Monument Walk',
#               'Navy Walk',
#               'Neptune Walk',
#               'Newport Walk',
#               'North Elliot Walk',
#               'North Elliott Walk',
#               'North Oxford Walk',
#               'Olive Walk',
#               'Pelham Walk',
#               'Pineapple Walk',
#               'Queens Walk',
#               'Roosevelt Walk',
#               'Sea Breeze Walk',
#               'Sidney Jonas Walk',
#               'Stagg Walk',
#               'Suffolk Walk',
#               'Ten Eyck Walk',
#               'Utica Walk',
#               'Washington Walk']),
#  'Warren': set(['Warren']),
#  'West': set(['Boardwalk West',
#               'Cadman Plaza West',
#               'Fdr Drive Service Road West',
#               'Gouverneur Slip West',
#               'Gramercy Park West',
#               'Grand Central Parkway Service Road West',
#               'Marginal Street West',
#               'Oceana Drive West',
#               'Plaza St West',
#               'Prospect Park West',
#               'Union Square West',
#               'Washington Square West',
#               'Williamsburg Street West']),
#  'Willoughby': set(['Willoughby']),
#  'X': set(['Avenue X']),
#  'Y': set(['Avenue Y']),
#  'Z': set(['Avenue Z']),
#  'ave': set(['5th ave']),
#  'avenue': set(['2nd avenue', 'Bedford avenue', 'Utica avenue']),
#  'bus_stop': set(['bus_stop']),
#  'st': set(['South 4th st', 'Union st']),
#  'street': set(['5th street',
#                 'Columbia street',
#                 'East 5th street',
#                 'Hudson street',
#                 'Lafayette street',
#                 'Mott street',
#                 'Mulberry street',
#                 'Pearl street',
#                 'Rivington street',
#                 'Union street'])}

# %%
def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

for street_type, ways in shh_street_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping, street_type_re)
        print name, "=>", better_name
# Out:
# Columbia Heights => Columbia Heights
# Aviation Rd => Aviation Road
# West 8th Steet => West 8th Steet
# Linden Boulevard Outer Eb Rb => Linden Boulevard Outer Eb Rb
# Bedford avenue => Bedford avenue
# 2nd avenue => 2nd avenue
# Utica avenue => Utica avenue
# Prospect Park Southwest => Prospect Park Southwest
# Graham Avenue #1 => Graham Avenue #1
# Greenwich Mews => Greenwich Mews
# Washington Mews => Washington Mews
# Willoughby => Willoughby
# Brighton 2nd Path => Brighton 2nd Path
# Brighton 10th Path => Brighton 10th Path
# Brighton 1st Path => Brighton 1st Path
# Avenue D => Avenue D
# Avenue H => Avenue H
# Avenue L => Avenue L
# Avenue P => Avenue P
# Avenue T => Avenue T
# Avenue X => Avenue X
# Northside Piers => Northside Piers
# Avenue Of The Finest => Avenue Of The Finest
# Exchange Alley => Exchange Alley
# Cortlandt Alley => Cortlandt Alley
# Mac Dougal Alley => Mac Dougal Alley
# Grace Court Alley => Grace Court Alley
# Freeman Alley => Freeman Alley
# Harrison Alley => Harrison Alley
# Theater Alley => Theater Alley
# bus_stop => bus_stop
# East Broadway => East Broadway
# West Broadway => West Broadway
# W. Broadway => W. Broadway
# Broadway => Broadway
# Warren => Warren
# Bayside => Bayside
# Oceana Drive West => Oceana Drive West
# Union Square West => Union Square West
# Grand Central Parkway Service Road West => Grand Central Parkway Service Road West
# Williamsburg Street West => Williamsburg Street West
# Boardwalk West => Boardwalk West
# Washington Square West => Washington Square West
# Prospect Park West => Prospect Park West
# Fdr Drive Service Road West => Fdr Drive Service Road West
# Gouverneur Slip West => Gouverneur Slip West
# Cadman Plaza West => Cadman Plaza West
# Gramercy Park West => Gramercy Park West
# Plaza St West => Plaza St West
# Marginal Street West => Marginal Street West
# Avenue Of Puerto Rico => Avenue Of Puerto Rico
# 5th street => 5th Street
# Union street => Union Street
# Columbia street => Columbia Street
# Hudson street => Hudson Street
# Lafayette street => Lafayette Street
# Mulberry street => Mulberry Street
# Pearl street => Pearl Street
# Mott street => Mott Street
# East 5th street => East 5th Street
# Rivington street => Rivington Street
# Middlemay Circle => Middlemay Circle
# Hamilton Circle => Hamilton Circle
# Marginal St East => Marginal St East
# Gramercy Park East => Gramercy Park East
# Gouverneur Slip East => Gouverneur Slip East
# Anthony J Falco Square East => Anthony J Falco Square East
# Oceana Drive East => Oceana Drive East
# Village Road East => Village Road East
# Union Square East => Union Square East
# Boardwalk East => Boardwalk East
# Park Drive East => Park Drive East
# Plaza Street East => Plaza Street East
# Washington Square East => Washington Square East
# Williamsburg Street East => Williamsburg Street East
# Cadman Plaza East => Cadman Plaza East
# Fdr Drive Service Road East => Fdr Drive Service Road East
# Washington Park => Washington Park
# Gramercy Park => Gramercy Park
# Remsen => Remsen
# Hanover Square #3 => Hanover Square #3
# Fort Hamilton => Fort Hamilton
# Harrison Street Suite PH => Harrison Street Suite PH
# 2nd Street #C => 2nd Street #C
# Avenue C => Avenue C
# Washington Ave. => Washington Ave.
# 70th Avenue, => 70th Avenue,
# Flatbush Avenue Extension => Flatbush Avenue Extension
# Eastern Parkway Extension => Eastern Parkway Extension
# Ste 300 => Ste 300
# Avenue K => Avenue K
# Lefrak City Plaza => Lefrak City Plaza
# Brookdale Plaza => Brookdale Plaza
# Chase Manhattan Plaza => Chase Manhattan Plaza
# Battery Park Plaza => Battery Park Plaza
# Marine View Plaza => Marine View Plaza
# Exchange Plaza => Exchange Plaza
# Federal Reserve Plaza => Federal Reserve Plaza
# Confucius Plaza => Confucius Plaza
# Hanover Plaza => Hanover Plaza
# Kings Plaza => Kings Plaza
# American Express Plaza => American Express Plaza
# Saint Andrews Plaza => Saint Andrews Plaza
# Pace Plaza => Pace Plaza
# Samuel Dickstein Plaza => Samuel Dickstein Plaza
# Newkirk Plaza => Newkirk Plaza
# Waterside Plaza => Waterside Plaza
# Haven Plaza => Haven Plaza
# Federal Plaza => Federal Plaza
# Western Union Plaza => Western Union Plaza
# Seaport Plaza => Seaport Plaza
# Wall Street Plaza => Wall Street Plaza
# Liberty Plaza => Liberty Plaza
# Police Plaza => Police Plaza
# State Street Plaza => State Street Plaza
# New York Plaza => New York Plaza
# Union Avenue 4B => Union Avenue 4B
# Avenue O => Avenue O
# Grand Army Plaza Oval => Grand Army Plaza Oval
# Stuyvesant Oval => Stuyvesant Oval
# Centre Mall => Centre Mall
# 305 Schermerhorn St., Brooklyn, NY 11217 => 305 Schermerhorn St., Brooklyn, NY 11217
# Avenue W => Avenue W
# 5th Ave => 5th Avenue
# Park Ave => Park Avenue
# Norman Ave => Norman Avenue
# 4th Ave => 4th Avenue
# 6th Ave => 6th Avenue
# Sheridan Loop => Sheridan Loop
# 14th Street Loop => 14th Street Loop
# Freeport Loop => Freeport Loop
# Elmira Loop => Elmira Loop
# Geneva Loop => Geneva Loop
# Ardsley Loop => Ardsley Loop
# Croton Loop => Croton Loop
# Hornell Loop => Hornell Loop
# Delmar Loop => Delmar Loop
# Bethel Loop => Bethel Loop
# Johnson Streeet => Johnson Streeet
# Bushwick => Bushwick
# Clinton => Clinton
# Horace Harding Expressway Sr S => Horace Harding Expressway Sr S
# Avenue S => Avenue S
# Avenue N => Avenue N
# Park Row => Park Row
# Warren St. => Warren St.
# Schermerhorn St. => Schermerhorn St.
# Devoe St. => Devoe St.
# Harrison St. => Harrison St.
# South 4th St. => South 4th St.
# Washington St. => Washington St.
# Henry St. => Henry St.
# 9th St. => 9th St.
# 11th St. => 11th St.
# 1st => 1st
# Gramercy Park North => Gramercy Park North
# Juniper Boulevard North => Juniper Boulevard North
# Queens Midtown Expressway Service Road North => Queens Midtown Expressway Service Road North
# Village Road North => Village Road North
# Shore Parkway Sr North => Shore Parkway Sr North
# Paerdegat Avenue North => Paerdegat Avenue North
# Washington Square North => Washington Square North
# Horace Harding Expressway Service Road North => Horace Harding Expressway Service Road North
# Mayfair Drive North => Mayfair Drive North
# Marshall Drive North => Marshall Drive North
# Barlow Drive North => Barlow Drive North
# Greenway North => Greenway North
# Gaylord Drive North => Gaylord Drive North
# Manhattan Avenue (2nd Floor) => Manhattan Avenue (2nd Floor)
# Vanderbilt => Vanderbilt
# Old Fulton => Old Fulton
# Main St., Suite 500 => Main St., Suite 500
# Queens Boulevard Wb Roadbed => Queens Boulevard Wb Roadbed
# Pennsylvania Avenue Nb Roadbed => Pennsylvania Avenue Nb Roadbed
# Delancey Street Eb Roadbed => Delancey Street Eb Roadbed
# Gateway Drive Westbound Roadbed => Gateway Drive Westbound Roadbed
# Kings Highway Westbound Roadbed => Kings Highway Westbound Roadbed
# Delancey Street Wb Roadbed => Delancey Street Wb Roadbed
# 4th Avenue Southbound Roadbed => 4th Avenue Southbound Roadbed
# Ocean Parkway Southbound Roadbed => Ocean Parkway Southbound Roadbed
# Linden Boulevard Eb Roadbed => Linden Boulevard Eb Roadbed
# Avenue B => Avenue B
# World Trade Center => World Trade Center
# One World Trade Center => One World Trade Center
# World Financial Center => World Financial Center
# Metrotech Center => Metrotech Center
# Avenue F => Avenue F
# Avenue J => Avenue J
# Avenue of the Americas
# => Avenue of the Americas
#
# Avenue Of The Americas => Avenue Of The Americas
# Avenue of the Americas => Avenue of the Americas
# Avenue R => Avenue R
# Avenue V => Avenue V
# Union Turnpike => Union Turnpike
# Avenue Z => Avenue Z
# 861 => 861
# North Elliott Walk => North Elliott Walk
# Atlantic Walk => Atlantic Walk
# Monument Walk => Monument Walk
# Bayside Walk => Bayside Walk
# Chester Walk => Chester Walk
# Bayway Walk => Bayway Walk
# Brant Walk => Brant Walk
# Hamilton Walk => Hamilton Walk
# Brighton 4th Walk => Brighton 4th Walk
# Kingsborough 5th Walk => Kingsborough 5th Walk
# Kingsborough 1st Walk => Kingsborough 1st Walk
# Olive Walk => Olive Walk
# Neptune Walk => Neptune Walk
# Ten Eyck Walk => Ten Eyck Walk
# Cumberland Walk => Cumberland Walk
# Kingsborough 2nd Walk => Kingsborough 2nd Walk
# Suffolk Walk => Suffolk Walk
# North Oxford Walk => North Oxford Walk
# Brighton 2nd Walk => Brighton 2nd Walk
# Brighton 1st Walk => Brighton 1st Walk
# Essex Walk => Essex Walk
# Hudson Walk => Hudson Walk
# Kingsborough 7th Walk => Kingsborough 7th Walk
# Irving Walk => Irving Walk
# Bath Walk => Bath Walk
# Brighton 3rd Walk => Brighton 3rd Walk
# North Elliot Walk => North Elliot Walk
# Kingsborough 6th Walk => Kingsborough 6th Walk
# Sidney Jonas Walk => Sidney Jonas Walk
# Lafayette Walk => Lafayette Walk
# Jones Walk => Jones Walk
# Lincoln Walk => Lincoln Walk
# Sea Breeze Walk => Sea Breeze Walk
# Navy Walk => Navy Walk
# Pelham Walk => Pelham Walk
# Clinton Walk => Clinton Walk
# Queens Walk => Queens Walk
# Fulton Walk => Fulton Walk
# Jamaica Walk => Jamaica Walk
# Washington Walk => Washington Walk
# Gotham Walk => Gotham Walk
# Devon Walk => Devon Walk
# Brighton 7th Walk => Brighton 7th Walk
# Marion Walk => Marion Walk
# Arcadia Walk => Arcadia Walk
# Fleet Walk => Fleet Walk
# Utica Walk => Utica Walk
# Bayview Walk => Bayview Walk
# East 4th Walk => East 4th Walk
# Kingsborough 3rd Walk => Kingsborough 3rd Walk
# Hillcrest Walk => Hillcrest Walk
# Roosevelt Walk => Roosevelt Walk
# Kildare Walk => Kildare Walk
# Pineapple Walk => Pineapple Walk
# Newport Walk => Newport Walk
# Deaville Walk => Deaville Walk
# Stagg Walk => Stagg Walk
# Brighton 5th Walk => Brighton 5th Walk
# Kingsborough 4th Walk => Kingsborough 4th Walk
# Broadway Atrium => Broadway Atrium
# Fairway Close => Fairway Close
# Ivy Close => Ivy Close
# 5th ave => 5th Avenue
# Horace Harding Expressway => Horace Harding Expressway
# Kings Highway => Kings Highway
# Bowery => Bowery
# The Bowery => The Bowery
# 218650358 => 218650358
# Ocean Promenade => Ocean Promenade
# Governors Island => Governors Island
# Beach Reservation => Beach Reservation
# River Terrace => River Terrace
# Harbor View Terrace => Harbor View Terrace
# Barwell Terrace => Barwell Terrace
# Wogan Terrace => Wogan Terrace
# Brighton 10th Terrace => Brighton 10th Terrace
# Banner 3rd Terrace => Banner 3rd Terrace
# Perry Terrace => Perry Terrace
# Oceana Terrace => Oceana Terrace
# Montague Terrace => Montague Terrace
# Lincoln Terrace => Lincoln Terrace
# Bay Cliff Terrace => Bay Cliff Terrace
# Bliss Terrace => Bliss Terrace
# Greenway Terrace => Greenway Terrace
# Ridgecrest Terrace => Ridgecrest Terrace
# Tudor Terrace => Tudor Terrace
# Park End Terrace => Park End Terrace
# Brighton 4th Terrace => Brighton 4th Terrace
# Losee Terrace => Losee Terrace
# Roxbury Terrace => Roxbury Terrace
# Kenmore Terrace => Kenmore Terrace
# Albemarle Terrace => Albemarle Terrace
# 56th Terrace => 56th Terrace
# Brighton 1st Terrace => Brighton 1st Terrace
# Louise Terrace => Louise Terrace
# Avenue A => Avenue A
# Harborside Fin Ctr => Harborside Fin Ctr
# Avenue I => Avenue I
# Avenue M => Avenue M
# Avenue U => Avenue U
# Avenue Y => Avenue Y
# Madison St => Madison Street
# Jackson St => Jackson Street
# Grand St => Grand Street
# Washington St => Washington Street
# 2nd St => 2nd Street
# Monroe St => Monroe Street
# 362nd Grand St => 362nd Grand Street
# 1st St => 1st Street
# Union St => Union Street
# Hudson St => Hudson Street
# Schermerhorn St => Schermerhorn Street
# Bloomfield St => Bloomfield Street
# 8th St => 8th Street
# Smith St & Bergen St => Smith St & Bergen Street
# River St => River Street
# State St & Water St => State St & Water Street
# Garden St => Garden Street
# Newark St => Newark Street
# Adams St => Adams Street
# N 7th St => N 7th Street
# E 15th St => E 15th Street
# Jefferson St => Jefferson Street
# 9th St => 9th Street
# Clinton St => Clinton Street
# Macdougal => Macdougal
# Colonial Gardens => Colonial Gardens
# 7th Avenue South => 7th Avenue South
# Gaylord Drive South => Gaylord Drive South
# Queens Midtown Expressway Service Road South => Queens Midtown Expressway Service Road South
# Paerdegat Avenue South => Paerdegat Avenue South
# Washington Square South => Washington Square South
# River Drive South => River Drive South
# Mayfair Drive South => Mayfair Drive South
# Park Avenue South => Park Avenue South
# Park Lane South => Park Lane South
# Greenway South => Greenway South
# Gramercy Park South => Gramercy Park South
# Horace Harding Expressway Service Road South => Horace Harding Expressway Service Road South
# Craig Road South => Craig Road South
# Village Road South => Village Road South
# Shore Parkway Sr South => Shore Parkway Sr South
# Marshall Drive South => Marshall Drive South
# Delancey St South => Delancey St South
# Juniper Boulevard South => Juniper Boulevard South
# Mc Guinness Boulevard South => Mc Guinness Boulevard South
# Barlow Drive South => Barlow Drive South
# Nostrand Avene => Nostrand Avene
# Gratta => Gratta
# N 9th ST => N 9th ST
# South 4th st => South 4th st
# Union st => Union st
# Asquith Crescent => Asquith Crescent
# Boelsen Crescent => Boelsen Crescent
# Slocum Crescent => Slocum Crescent
# Dieterle Crescent => Dieterle Crescent
# Cromwell Crescent => Cromwell Crescent
# Ellwell Crescent => Ellwell Crescent
# Mt Olivet Crescent => Mt Olivet Crescent
# Peck Slip => Peck Slip
# Old Slip => Old Slip
# Pike Slip => Pike Slip
# Rutgers Slip => Rutgers Slip
# Coenties Slip => Coenties Slip
# Catherine Slip => Catherine Slip
# Washington Square Village => Washington Square Village
# Marin Blvd => Marin Boulevard
# Queens Blvd => Queens Boulevard
# Woodhaven Blvd => Woodhaven Boulevard
# Hillside Avenue Rockaways => Hillside Avenue Rockaways
# MetroTech => MetroTech
